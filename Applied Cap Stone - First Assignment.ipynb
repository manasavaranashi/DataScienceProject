# %% [markdown]
# <img src="https://www.vmahs.org/wp-content/uploads/2019/07/Capstone_Wordbubble-w.jpg" width="100" height="80" align="left">
#
# ## This notebook will be mainly used for the capstone project.

# %%
import pandas as pd
import numpy as np

print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
